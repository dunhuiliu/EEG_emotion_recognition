# %% [markdown]
# # 类比实验
# - 32个受试者，按比例划分数据集，进行八折交叉验证
# - 把测试受试者随机选择一个训练好的模型（不选择Wasserstein距离最近的模型）作为对比实验
# - 与单受试者模型做对比，期望结果，准确率相差不多或比单受试者模型准确率略低
# - 与所有受试者公用一个模型做对比，期望结果，比所有受试者公用模型准确率高很多

# %%
#加载飞桨、Numpy和相关类库
import numpy as np
import pyeeg as pe
import os
import random
import time

from PIL import Image
import matplotlib.pyplot as plt
from matplotlib import pyplot

from scipy.stats import wasserstein_distance

# %%
#加载一个受试者
def De_baseline(sub):
    dir='E:\JupyterNotebookWorkSpace\dataSet\\1280x258050(32x8064+2).npy'
    data=np.load(dir)
    subData = data[sub * 40 : (sub + 1) * 40]
    subData[: , -2:] = np.where(subData[: , -2:] >= 5 , 1 , -1)
    return subData

# %%
#数据集切60片，基线单独返回
def Data_set_partition(subData):
    features = subData[:,:-2]
    labels = subData[:,-2:]
    features = features.reshape(40,32,-1)
    baseline = features[:,:,:384]
    features = features[:,:,384:]
    
    dataList = []
    for i in range(40):
        for j in range(60):
            dataList.append(np.append(features[i][ : , j * 128 : (j + 1) * 128].reshape(-1) , labels[i]))

    dataList = np.array(dataList)

    return dataList, baseline

# %%
#特征提取
def feature_extraction(trainData, baseline):

    band = [4,8,13,16,30,45] #5 bands    band = [4,8,12,16,25,45]    
    window_size = 128 #Averaging band power of 1 sec
    step_size = 128 #Each 1 sec update once
    sample_rate = 128 #Sampling rate of 128 Hz

    features = trainData[:,:-2]
    labels = trainData[:,-2:]
    features = features.reshape(features.shape[0],32,128)

    newData=[]
    for i in range(features.shape[0]):    #样本数
        channel_features=[]
        for j in range(32):
            X = features[i][j]
            Y = pe.bin_power(X, band, sample_rate)
            channel_features += list(Y[0])
            ###################################################################################
        channel_features += list(labels[i])    #添加标签
        newData.append(channel_features)
    trainData = np.array(newData)

    #计算频域基线
    features = baseline

    newData=[]
    for i in range(features.shape[0]):    #电影数
        channel_features=[]
        for k in range(3):
            baseline_feature = []
            for j in range(32):
                X = features[i][j][k * 128 : (k + 1) * 128]
                Y = pe.bin_power(X, band, sample_rate)
                baseline_feature += list(Y[0])
            channel_features.append(baseline_feature)    #求基线的均值还是均值的基线？
        newData.append(np.array(channel_features).mean(axis = 0))
    newData = np.array(newData)
    
# 减去基线特征
    for i in range(40):
        trainData[i * 60 : (i + 1) * 60 , : 160] -= newData[i]

    return trainData

# %%
# AllSubFreq = []    #保存所有受试者的频域特征32*2400*160(不含标签)
# for sub in range(32):
#     SubData = De_baseline(sub)
#     dataList, baseline = Data_set_partition(SubData)
#     trainData = feature_extraction(dataList, baseline)
#     AllSubFreq.append(trainData)
# AllSubFreq = np.array(AllSubFreq)
# print(AllSubFreq.shape)
# AllSubFreq = np.reshape(AllSubFreq, (-1, 162))
# print(AllSubFreq.shape)
# np.save("./with_label_DE_baseline_AllSubFreq.npy",AllSubFreq)

# %%
# # 数据集划分

# def Data_set_partition(data, ratio, random_state = int(time.time())):
#     np.random.seed(random_state)
#     np.random.shuffle(data)
#     trainSet = data[:int(data.shape[0] * ratio)]
#     testSet = data[int(data.shape[0] * ratio):]
#     print('trainSet.shape = ', trainSet.shape)
#     print('testSet.shape = ', testSet.shape)
#     np.save("./trainSet.npy", trainSet)
#     np.save("./testSet.npy", testSet)

# allSub = np.load("./with_label_DE_baseline_AllSubFreq.npy")
# ratio = 0.8
# Data_set_partition(allSub, ratio, random_state = 0)

# %%
# #计算KL散度
# import numpy as np
# import scipy.stats

# # 利用scipy API进行计算
# # scipy计算函数可以处理非归一化情况，因此这里使用
# # scipy.stats.entropy(x, y)或scipy.stats.entropy(px, py)均可
# KL = np.zeros((32,32))
# for i in range(32):
#     for j in range(32):
#         x = AllSubFreq[i]
#         y = AllSubFreq[j]
#         KL[i][j] = scipy.stats.entropy(x, y)
# print(KL)
# np.save("work/data/KL_AllSubFreq.npy",KL)

# %%
# #计算JS散度

# import numpy as np
# import scipy.stats

# def JS_divergence(p,q):
#     M=(p+q)/2
#     return 0.5*scipy.stats.entropy(p, M)+0.5*scipy.stats.entropy(q, M)

# JS = np.zeros((32,32))
# for i in range(32):
#     for j in range(32):
#         x = AllSubFreq[i]
#         y = AllSubFreq[j]
#         JS[i][j] = JS_divergence(x, y)
# np.set_printoptions(threshold = 1e6)
# print(JS)
# np.save("work/data/JS_AllSubFreq.npy",JS)

# %%
# def Gaussian_normalization(trainData, testData):
#     """高斯归一化"""

#     #训练样本归一化
#     feature=trainData[:,:-2]
#     mean=feature.mean(axis=0)
#     std=feature.std(axis=0)
#     feature-=mean
#     feature/=std
#     trainData[:,:-2] = feature

#     #测试样本归一化
#     feature=testData[:,:-2]
#     feature-=mean
#     feature/=std
#     testData[:,:-2] = feature

#     return trainData, testData

# %%
#使用Wasserstein距离进行K-means聚类
from scipy.stats import wasserstein_distance

class K_Means(object):
    # k是分组数；tolerance‘中心点误差’；max_iter是迭代次数
    def __init__(self, k=2, tolerance=0.0001, max_iter=300):
        self.k_ = k
        self.tolerance_ = tolerance
        self.max_iter_ = max_iter

    def fit(self, data):
        self.centers_ = {}
        for i in range(self.k_):
            self.centers_[i] = data[i]

        for i in range(self.max_iter_):
            self.clf_ = {}
            for j in range(self.k_):
                self.clf_[j] = []
            # print("质点:",self.centers_)
            for SubIndexId, feature in enumerate(data):
                # distances = [np.linalg.norm(feature-self.centers[center]) for center in self.centers]
                distances = []
                for center in self.centers_:
                    # 欧拉距离
                    # np.sqrt(np.sum((features-self.centers_[center])**2))
                    distances.append(np.linalg.norm(feature - self.centers_[center]))#wasserstein_distance(feature, self.centers_[center])
                    
                classification = distances.index(min(distances))
                self.clf_[classification].append(SubIndexId)

            # print("分组情况:",self.clf_)
            prev_centers = dict(self.centers_)
            
            self.flag = True    #聚类是否成功
            for c in self.clf_:
                if(len(self.clf_[c]) == 0):
                    self.flag = False
                    print('\n')
                    print('第{}次迭代：'.format(i))
                    print('************************聚类中心无样本截止！******************************')
                    return
                self.centers_[c] = np.average(data[np.array(self.clf_[c])], axis=0)

            # '中心点'是否在误差范围
            optimized = True
            for center in self.centers_:
                org_centers = prev_centers[center]
                cur_centers = self.centers_[center]
                if np.sum((cur_centers - org_centers) / org_centers * 100.0) > self.tolerance_:
                    optimized = False
            if optimized:
                print('迭代次数：', i)
                break

    def predict(self, p_data):
        allIndex = []
        for oneTestSample in p_data:
            distances = [np.linalg.norm(oneTestSample - self.centers_[center]) for center in self.centers_] #wasserstein_distance(oneTestSample, self.centers_[center])
            index = distances.index(min(distances))
            allIndex.append(index)
        return np.array(allIndex)

# %%
def W_K_means(n_cluster, trainSet):
    AllSubFreq = trainSet
    #print(AllSubFreq.shape)

    k_means = K_Means(k=n_cluster)
    k_means.fit(data  = AllSubFreq)
    return k_means
    # print(k_means.centers_)
    # for center in k_means.centers_:
    #     pyplot.scatter(k_means.centers_[center][0], k_means.centers_[center][1], marker='*', s=150)

    # for cat in k_means.clf_:
    #     for point in k_means.clf_[cat]:
    #         pyplot.scatter(point[0], point[1], c=('r' if cat == 0 else 'b'))

    # predict = [[2, 1],[6, 9]]
    # for feature in predict:
    #     cat = k_means.predict(feature)
    #     pyplot.scatter(feature[0], feature[1], c=('r' if cat == 0 else 'b'), marker='x')

    # pyplot.show()

# %%
from sklearn import svm
from sklearn.preprocessing import normalize
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score

def trainModel(trainData, testData, Edim, num_cluster, modelId):
    dim = Edim
    
    trainLabel = trainData[:, -2:]
    trainData = trainData[:, :-2]
    trainLabel = trainLabel[:, dim]
    
    testLabel = testData[:, -2:]
    testData = testData[:, :-2]
    testLabel = testLabel[:, dim]
    print('model_{}\ttrainNum: {}\ttestNum: {}，训练：测试 = {:.2f}'.format(modelId, trainData.shape[0], testData.shape[0], trainData.shape[0] / testData.shape[0]),end = '\t')
    
#     svmModel = svm.SVC()
#     svmModel.fit(data_training, valtrain) 
#     ypredict=svmModel.predict(data_testing)
#     print("SVMacc：",accuracy_score(ypredict,valtest)) 

    rfModel = RandomForestClassifier(n_estimators=512, n_jobs=8)
    rfModel.fit(trainData, trainLabel)
    ypredict = rfModel.predict(testData)
    acc = accuracy_score(ypredict,testLabel)
    print("acc = {}".format(acc))
    return acc, testData.shape[0]

# %%
# 开始对训练集聚类
valence_or_arousal = -2  #-2 : valence;-1 : arousal

trainSet = np.load("./trainSet.npy")
trainFeature = trainSet[:, :-2]
testSet = np.load("./testSet.npy")
testFeature = testSet[:, :-2]
print('trainSet.shape = {}\ttestSet.shape = {}'.format(trainSet.shape,
                                                       testSet.shape))
allAcc = []
meanAcc = []
for num_cluster in range(1, 33):  #12
    print('K = {}\t'.format(num_cluster), end='')
    #    *** 在这里我们关心哪些人的哪些视频被聚在了一起 ***    #
    k_means_machine = W_K_means(num_cluster, trainFeature)
    if (k_means_machine.flag == False):
        continue
    # 使用建立的K-means模型对测试集分类
    allIndex = k_means_machine.predict(testFeature)

    classList = k_means_machine.clf_
    clusterMean = []
    K_ACC = []
    for j in range(len(classList)):
        accDict = {}
        testData = testSet[allIndex == j]
        acc, testNum = trainModel(trainSet[np.array(classList[j])],
                                  testData,
                                  valence_or_arousal,
                                  num_cluster,
                                  modelId=j)
        accDict[acc] = testNum
        K_ACC.append(accDict)
        clusterMean.append(acc * testNum)
    allAcc.append(K_ACC)
    clusterMean = np.array(clusterMean).sum() / testSet.shape[0]
    meanAcc.append(clusterMean)
np.save('meanAcc.npy', np.array(meanAcc))
np.save('allAcc.npy', np.array(allAcc))
# Out:
# trainSet.shape = (61440, 162)	testSet.shape = (15360, 162)
# K = 1	迭代次数： 0
# model_0	trainNum: 61440	testNum: 15360，训练：测试 = 4.00	acc = 0.8475260416666667
# K = 2	迭代次数： 11
# model_0	trainNum: 59655	testNum: 14892，训练：测试 = 4.01	acc = 0.8451517593338705
# model_1	trainNum: 1785	testNum: 468，训练：测试 = 3.81	acc = 0.9551282051282052
# K = 3	迭代次数： 8
# model_0	trainNum: 6528	testNum: 1630，训练：测试 = 4.00	acc = 0.7349693251533742
# model_1	trainNum: 1756	testNum: 460，训练：测试 = 3.82	acc = 0.95
# model_2	trainNum: 53156	testNum: 13270，训练：测试 = 4.01	acc = 0.852750565184627
# K = 4	迭代次数： 20
# model_0	trainNum: 3110	testNum: 778，训练：测试 = 4.00	acc = 0.7107969151670951
# model_1	trainNum: 1401	testNum: 366，训练：测试 = 3.83	acc = 0.9480874316939891
# model_2	trainNum: 4334	testNum: 1086，训练：测试 = 3.99	acc = 0.9456721915285451
# model_3	trainNum: 52595	testNum: 13130，训练：测试 = 4.01	acc = 0.8380807311500381
# K = 5	迭代次数： 30
# model_0	trainNum: 1890	testNum: 486，训练：测试 = 3.89	acc = 0.6604938271604939
# model_1	trainNum: 2480	testNum: 613，训练：测试 = 4.05	acc = 0.9510603588907015
# model_2	trainNum: 17965	testNum: 4567，训练：测试 = 3.93	acc = 0.9209546748412525
# model_3	trainNum: 37775	testNum: 9346，训练：测试 = 4.04	acc = 0.7993794136528997
# model_4	trainNum: 1330	testNum: 348，训练：测试 = 3.82	acc = 0.9568965517241379
# K = 6	迭代次数： 58
# model_0	trainNum: 1767	testNum: 454，训练：测试 = 3.89	acc = 0.6651982378854625
# model_1	trainNum: 1289	testNum: 347，训练：测试 = 3.71	acc = 0.968299711815562
# model_2	trainNum: 3499	testNum: 855，训练：测试 = 4.09	acc = 0.9239766081871345
# model_3	trainNum: 33253	testNum: 8202，训练：测试 = 4.05	acc = 0.7938307729821995
# model_4	trainNum: 1260	testNum: 323，训练：测试 = 3.90	acc = 0.9504643962848297
# model_5	trainNum: 20372	testNum: 5179，训练：测试 = 3.93	acc = 0.9073180150608225
# K = 7	迭代次数： 67
# model_0	trainNum: 4601	testNum: 1125，训练：测试 = 4.09	acc = 0.7271111111111112
# model_1	trainNum: 1226	testNum: 332，训练：测试 = 3.69	acc = 0.9698795180722891
# model_2	trainNum: 3272	testNum: 800，训练：测试 = 4.09	acc = 0.925
# model_3	trainNum: 33452	testNum: 8299，训练：测试 = 4.03	acc = 0.8023858296180263
# model_4	trainNum: 1260	testNum: 323，训练：测试 = 3.90	acc = 0.9659442724458205
# model_5	trainNum: 16911	testNum: 4291，训练：测试 = 3.94	acc = 0.9163365182941039
# model_6	trainNum: 718	testNum: 190，训练：测试 = 3.78	acc = 0.6421052631578947
# K = 8	迭代次数： 66
# model_0	trainNum: 4560	testNum: 1123，训练：测试 = 4.06	acc = 0.7346393588601959
# model_1	trainNum: 1195	testNum: 321，训练：测试 = 3.72	acc = 0.9844236760124611
# model_2	trainNum: 3241	testNum: 789，训练：测试 = 4.11	acc = 0.9226869455006337
# model_3	trainNum: 33399	testNum: 8287，训练：测试 = 4.03	acc = 0.8033063834922167
# model_4	trainNum: 1257	testNum: 324，训练：测试 = 3.88	acc = 0.9598765432098766
# model_5	trainNum: 16889	testNum: 4288，训练：测试 = 3.94	acc = 0.9151119402985075
# model_6	trainNum: 714	testNum: 188，训练：测试 = 3.80	acc = 0.6542553191489362
# model_7	trainNum: 185	testNum: 40，训练：测试 = 4.62	acc = 0.8
# K = 9	迭代次数： 54
# model_0	trainNum: 4144	testNum: 1039，训练：测试 = 3.99	acc = 0.7256977863330125
# model_1	trainNum: 1199	testNum: 323，训练：测试 = 3.71	acc = 0.9907120743034056
# model_2	trainNum: 3114	testNum: 766，训练：测试 = 4.07	acc = 0.9138381201044387
# model_3	trainNum: 33265	testNum: 8243，训练：测试 = 4.04	acc = 0.8016498847506975
# model_4	trainNum: 1257	testNum: 324，训练：测试 = 3.88	acc = 0.9598765432098766
# model_5	trainNum: 16540	testNum: 4204，训练：测试 = 3.93	acc = 0.9107992388201712
# model_6	trainNum: 641	testNum: 167，训练：测试 = 3.84	acc = 0.6407185628742516
# model_7	trainNum: 182	testNum: 37，训练：测试 = 4.92	acc = 0.8378378378378378
# model_8	trainNum: 1098	testNum: 257，训练：测试 = 4.27	acc = 0.9766536964980544
# K = 10	迭代次数： 65
# model_0	trainNum: 1451	testNum: 365，训练：测试 = 3.98	acc = 0.6410958904109589
# model_1	trainNum: 933	testNum: 258，训练：测试 = 3.62	acc = 0.9806201550387597
# model_2	trainNum: 2639	testNum: 659，训练：测试 = 4.00	acc = 0.91350531107739
# model_3	trainNum: 7892	testNum: 1928，训练：测试 = 4.09	acc = 0.7453319502074689
# model_4	trainNum: 1240	testNum: 318，训练：测试 = 3.90	acc = 0.9591194968553459
# model_5	trainNum: 14110	testNum: 3573，训练：测试 = 3.95	acc = 0.922474111390988
# model_6	trainNum: 357	testNum: 93，训练：测试 = 3.84	acc = 0.6989247311827957
# model_7	trainNum: 184	testNum: 37，训练：测试 = 4.97	acc = 0.8108108108108109
# model_8	trainNum: 1234	testNum: 296，训练：测试 = 4.17	acc = 0.9594594594594594
# model_9	trainNum: 31400	testNum: 7833，训练：测试 = 4.01	acc = 0.8169283799310609
# K = 11	迭代次数： 105
# model_0	trainNum: 1248	testNum: 309，训练：测试 = 4.04	acc = 0.656957928802589
# model_1	trainNum: 804	testNum: 226，训练：测试 = 3.56	acc = 0.9203539823008849
# model_2	trainNum: 3011	testNum: 733，训练：测试 = 4.11	acc = 0.9167803547066848
# model_3	trainNum: 6930	testNum: 1697，训练：测试 = 4.08	acc = 0.7348261638185032
# model_4	trainNum: 541	testNum: 131，训练：测试 = 4.13	acc = 1.0
# model_5	trainNum: 14927	testNum: 3808，训练：测试 = 3.92	acc = 0.9188550420168067
# model_6	trainNum: 325	testNum: 92，训练：测试 = 3.53	acc = 0.6521739130434783
# model_7	trainNum: 182	testNum: 38，训练：测试 = 4.79	acc = 0.8157894736842105
# model_8	trainNum: 1093	testNum: 259，训练：测试 = 4.22	acc = 0.9691119691119691
# model_9	trainNum: 31175	testNum: 7750，训练：测试 = 4.02	acc = 0.8149677419354838
# model_10	trainNum: 1204	testNum: 317，训练：测试 = 3.80	acc = 0.9779179810725552
# K = 12	迭代次数： 50
# model_0	trainNum: 1252	testNum: 307，训练：测试 = 4.08	acc = 0.6612377850162866
# model_1	trainNum: 698	testNum: 194，训练：测试 = 3.60	acc = 0.8762886597938144
# model_2	trainNum: 2425	testNum: 619，训练：测试 = 3.92	acc = 0.9305331179321487
# model_3	trainNum: 6815	testNum: 1668，训练：测试 = 4.09	acc = 0.7290167865707434
# model_4	trainNum: 870	testNum: 221，训练：测试 = 3.94	acc = 0.9502262443438914
# model_5	trainNum: 13939	testNum: 3542，训练：测试 = 3.94	acc = 0.9150197628458498
# model_6	trainNum: 324	testNum: 92，训练：测试 = 3.52	acc = 0.717391304347826
# model_7	trainNum: 936	testNum: 209，训练：测试 = 4.48	acc = 0.9282296650717703
# model_8	trainNum: 1058	testNum: 247，训练：测试 = 4.28	acc = 0.9635627530364372
# model_9	trainNum: 30761	testNum: 7669，训练：测试 = 4.01	acc = 0.8092319728778198
# model_10	trainNum: 1066	testNum: 274，训练：测试 = 3.89	acc = 0.9817518248175182
# model_11	trainNum: 1296	testNum: 318，训练：测试 = 4.08	acc = 0.8930817610062893
# K = 13	迭代次数： 105
# model_0	trainNum: 1715	testNum: 432，训练：测试 = 3.97	acc = 0.6736111111111112
# model_1	trainNum: 772	testNum: 221，训练：测试 = 3.49	acc = 0.9095022624434389
# model_2	trainNum: 10914	testNum: 2819，训练：测试 = 3.87	acc = 0.9219581411848173
# model_3	trainNum: 10056	testNum: 2500，训练：测试 = 4.02	acc = 0.7416
# model_4	trainNum: 631	testNum: 149，训练：测试 = 4.23	acc = 0.9865771812080537
# model_5	trainNum: 1256	testNum: 299，训练：测试 = 4.20	acc = 0.9665551839464883
# model_6	trainNum: 375	testNum: 101，训练：测试 = 3.71	acc = 0.6633663366336634
# model_7	trainNum: 184	testNum: 38，训练：测试 = 4.84	acc = 0.7631578947368421
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 31696	testNum: 7854，训练：测试 = 4.04	acc = 0.8300229182582124
# model_10	trainNum: 881	testNum: 197，训练：测试 = 4.47	acc = 0.9289340101522843
# model_11	trainNum: 1251	testNum: 307，训练：测试 = 4.07	acc = 0.8892508143322475
# model_12	trainNum: 1661	testNum: 433，训练：测试 = 3.84	acc = 0.9561200923787528
# K = 14	迭代次数： 82
# model_0	trainNum: 654	testNum: 160，训练：测试 = 4.09	acc = 0.6875
# model_1	trainNum: 675	testNum: 187，训练：测试 = 3.61	acc = 0.8716577540106952
# model_2	trainNum: 2479	testNum: 635，训练：测试 = 3.90	acc = 0.9338582677165355
# model_3	trainNum: 5079	testNum: 1242，训练：测试 = 4.09	acc = 0.7415458937198067
# model_4	trainNum: 840	testNum: 214，训练：测试 = 3.93	acc = 0.9626168224299065
# model_5	trainNum: 1215	testNum: 290，训练：测试 = 4.19	acc = 0.9724137931034482
# model_6	trainNum: 329	testNum: 98，训练：测试 = 3.36	acc = 0.5714285714285714
# model_7	trainNum: 14651	testNum: 3735，训练：测试 = 3.92	acc = 0.9103078982597055
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 32099	testNum: 7967，训练：测试 = 4.03	acc = 0.8023095267980419
# model_10	trainNum: 940	testNum: 209，训练：测试 = 4.50	acc = 0.9330143540669856
# model_11	trainNum: 1316	testNum: 323，训练：测试 = 4.07	acc = 0.8792569659442725
# model_12	trainNum: 1066	testNum: 279，训练：测试 = 3.82	acc = 0.985663082437276
# model_13	trainNum: 49	testNum: 11，训练：测试 = 4.45	acc = 0.8181818181818182
# K = 15	迭代次数： 71
# model_0	trainNum: 651	testNum: 160，训练：测试 = 4.07	acc = 0.6875
# model_1	trainNum: 655	testNum: 188，训练：测试 = 3.48	acc = 0.8882978723404256
# model_2	trainNum: 2454	testNum: 634，训练：测试 = 3.87	acc = 0.9321766561514195
# model_3	trainNum: 4938	testNum: 1204，训练：测试 = 4.10	acc = 0.7267441860465116
# model_4	trainNum: 868	testNum: 220，训练：测试 = 3.95	acc = 0.9545454545454546
# model_5	trainNum: 1036	testNum: 235，训练：测试 = 4.41	acc = 0.9659574468085106
# model_6	trainNum: 328	testNum: 97，训练：测试 = 3.38	acc = 0.5876288659793815
# model_7	trainNum: 14694	testNum: 3759，训练：测试 = 3.91	acc = 0.9124767225325885
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 31856	testNum: 7899，训练：测试 = 4.03	acc = 0.8035194328395999
# model_10	trainNum: 940	testNum: 209，训练：测试 = 4.50	acc = 0.9234449760765551
# model_11	trainNum: 1306	testNum: 321，训练：测试 = 4.07	acc = 0.8940809968847352
# model_12	trainNum: 1052	testNum: 270，训练：测试 = 3.90	acc = 0.9814814814814815
# model_13	trainNum: 580	testNum: 145，训练：测试 = 4.00	acc = 0.7724137931034483
# model_14	trainNum: 34	testNum: 9，训练：测试 = 3.78	acc = 0.7777777777777778
# K = 16	迭代次数： 66
# model_0	trainNum: 599	testNum: 149，训练：测试 = 4.02	acc = 0.6778523489932886
# model_1	trainNum: 656	testNum: 188，训练：测试 = 3.49	acc = 0.8776595744680851
# model_2	trainNum: 2513	testNum: 650，训练：测试 = 3.87	acc = 0.936923076923077
# model_3	trainNum: 4671	testNum: 1143，训练：测试 = 4.09	acc = 0.7375328083989501
# model_4	trainNum: 868	testNum: 220，训练：测试 = 3.95	acc = 0.9545454545454546
# model_5	trainNum: 1017	testNum: 229，训练：测试 = 4.44	acc = 0.9606986899563319
# model_6	trainNum: 326	testNum: 96，训练：测试 = 3.40	acc = 0.6041666666666666
# model_7	trainNum: 1596	testNum: 388，训练：测试 = 4.11	acc = 0.9432989690721649
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 14317	testNum: 3677，训练：测试 = 3.89	acc = 0.9059015501767745
# model_10	trainNum: 771	testNum: 175，训练：测试 = 4.41	acc = 0.9085714285714286
# model_11	trainNum: 1294	testNum: 319，训练：测试 = 4.06	acc = 0.8996865203761756
# model_12	trainNum: 1067	testNum: 279，训练：测试 = 3.82	acc = 0.982078853046595
# model_13	trainNum: 578	testNum: 145，训练：测试 = 3.99	acc = 0.7724137931034483
# model_14	trainNum: 34	testNum: 9，训练：测试 = 3.78	acc = 0.7777777777777778
# model_15	trainNum: 31085	testNum: 7683，训练：测试 = 4.05	acc = 0.8009891969282832
# K = 17	迭代次数： 80
# model_0	trainNum: 1306	testNum: 326，训练：测试 = 4.01	acc = 0.6840490797546013
# model_1	trainNum: 655	testNum: 188，训练：测试 = 3.48	acc = 0.8829787234042553
# model_2	trainNum: 2370	testNum: 609，训练：测试 = 3.89	acc = 0.9326765188834154
# model_3	trainNum: 7169	testNum: 1736，训练：测试 = 4.13	acc = 0.738479262672811
# model_4	trainNum: 868	testNum: 220，训练：测试 = 3.95	acc = 0.9545454545454546
# model_5	trainNum: 1030	testNum: 237，训练：测试 = 4.35	acc = 0.9704641350210971
# model_6	trainNum: 207	testNum: 49，训练：测试 = 4.22	acc = 0.7346938775510204
# model_7	trainNum: 1555	testNum: 408，训练：测试 = 3.81	acc = 0.9068627450980392
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 12370	testNum: 3154，训练：测试 = 3.92	acc = 0.9223208623969562
# model_10	trainNum: 939	testNum: 209，训练：测试 = 4.49	acc = 0.9330143540669856
# model_11	trainNum: 1286	testNum: 317，训练：测试 = 4.06	acc = 0.8927444794952681
# model_12	trainNum: 1026	testNum: 263，训练：测试 = 3.90	acc = 0.9809885931558935
# model_13	trainNum: 569	testNum: 140，训练：测试 = 4.06	acc = 0.7785714285714286
# model_14	trainNum: 34	testNum: 9，训练：测试 = 3.78	acc = 0.6666666666666666
# model_15	trainNum: 29699	testNum: 7396，训练：测试 = 4.02	acc = 0.8177393185505679
# model_16	trainNum: 309	testNum: 89，训练：测试 = 3.47	acc = 0.550561797752809
# K = 18	迭代次数： 140
# model_0	trainNum: 1223	testNum: 308，训练：测试 = 3.97	acc = 0.6753246753246753
# model_1	trainNum: 497	testNum: 128，训练：测试 = 3.88	acc = 0.9609375
# model_2	trainNum: 2430	testNum: 634，训练：测试 = 3.83	acc = 0.9242902208201893
# model_3	trainNum: 6680	testNum: 1619，训练：测试 = 4.13	acc = 0.7399629400864731
# model_4	trainNum: 659	testNum: 189，训练：测试 = 3.49	acc = 0.8783068783068783
# model_5	trainNum: 1039	testNum: 238，训练：测试 = 4.37	acc = 0.9705882352941176
# model_6	trainNum: 199	testNum: 48，训练：测试 = 4.15	acc = 0.7291666666666666
# model_7	trainNum: 1595	testNum: 385，训练：测试 = 4.14	acc = 0.9454545454545454
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 13008	testNum: 3331，训练：测试 = 3.91	acc = 0.9135394776343441
# model_10	trainNum: 771	testNum: 175，训练：测试 = 4.41	acc = 0.9142857142857143
# model_11	trainNum: 1289	testNum: 318，训练：测试 = 4.05	acc = 0.8962264150943396
# model_12	trainNum: 723	testNum: 182，训练：测试 = 3.97	acc = 0.9835164835164835
# model_13	trainNum: 566	testNum: 136，训练：测试 = 4.16	acc = 0.7867647058823529
# model_14	trainNum: 33	testNum: 9，训练：测试 = 3.67	acc = 0.6666666666666666
# model_15	trainNum: 29505	testNum: 7342，训练：测试 = 4.02	acc = 0.8083628439117406
# model_16	trainNum: 307	testNum: 88，训练：测试 = 3.49	acc = 0.5681818181818182
# model_17	trainNum: 868	testNum: 220，训练：测试 = 3.95	acc = 0.9545454545454546
# K = 19	迭代次数： 146
# model_0	trainNum: 959	testNum: 232，训练：测试 = 4.13	acc = 0.7025862068965517
# model_1	trainNum: 477	testNum: 123，训练：测试 = 3.88	acc = 0.967479674796748
# model_2	trainNum: 2056	testNum: 542，训练：测试 = 3.79	acc = 0.9298892988929889
# model_3	trainNum: 23086	testNum: 5702，训练：测试 = 4.05	acc = 0.7784987723605752
# model_4	trainNum: 658	testNum: 187，训练：测试 = 3.52	acc = 0.9090909090909091
# model_5	trainNum: 1003	testNum: 232，训练：测试 = 4.32	acc = 0.9655172413793104
# model_6	trainNum: 182	testNum: 44，训练：测试 = 4.14	acc = 0.7045454545454546
# model_7	trainNum: 1444	testNum: 389，训练：测试 = 3.71	acc = 0.9023136246786633
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 7801	testNum: 2000，训练：测试 = 3.90	acc = 0.91
# model_10	trainNum: 893	testNum: 203，训练：测试 = 4.40	acc = 0.9359605911330049
# model_11	trainNum: 1210	testNum: 291，训练：测试 = 4.16	acc = 0.9003436426116839
# model_12	trainNum: 698	testNum: 173，训练：测试 = 4.03	acc = 0.9826589595375722
# model_13	trainNum: 552	testNum: 135，训练：测试 = 4.09	acc = 0.7703703703703704
# model_14	trainNum: 33	testNum: 9，训练：测试 = 3.67	acc = 0.7777777777777778
# model_15	trainNum: 14688	testNum: 3676，训练：测试 = 4.00	acc = 0.8748639825897715
# model_16	trainNum: 321	testNum: 93，训练：测试 = 3.45	acc = 0.6021505376344086
# model_17	trainNum: 869	testNum: 221，训练：测试 = 3.93	acc = 0.9547511312217195
# model_18	trainNum: 4462	testNum: 1098，训练：测试 = 4.06	acc = 0.7486338797814208
# K = 20	迭代次数： 200
# model_0	trainNum: 959	testNum: 230，训练：测试 = 4.17	acc = 0.6652173913043479
# model_1	trainNum: 477	testNum: 123，训练：测试 = 3.88	acc = 0.975609756097561
# model_2	trainNum: 2062	testNum: 541，训练：测试 = 3.81	acc = 0.933456561922366
# model_3	trainNum: 22272	testNum: 5519，训练：测试 = 4.04	acc = 0.7829316905236456
# model_4	trainNum: 657	testNum: 188，训练：测试 = 3.49	acc = 0.8776595744680851
# model_5	trainNum: 984	testNum: 226，训练：测试 = 4.35	acc = 0.9601769911504425
# model_6	trainNum: 182	testNum: 44，训练：测试 = 4.14	acc = 0.75
# model_7	trainNum: 1436	testNum: 389，训练：测试 = 3.69	acc = 0.9023136246786633
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 7667	testNum: 1969，训练：测试 = 3.89	acc = 0.9121381411884205
# model_10	trainNum: 889	testNum: 200，训练：测试 = 4.45	acc = 0.925
# model_11	trainNum: 1208	testNum: 291，训练：测试 = 4.15	acc = 0.9037800687285223
# model_12	trainNum: 698	testNum: 172，训练：测试 = 4.06	acc = 0.9825581395348837
# model_13	trainNum: 226	testNum: 41，训练：测试 = 5.51	acc = 0.8536585365853658
# model_14	trainNum: 34	testNum: 9，训练：测试 = 3.78	acc = 0.6666666666666666
# model_15	trainNum: 13719	testNum: 3443，训练：测试 = 3.98	acc = 0.8884693581179204
# model_16	trainNum: 319	testNum: 93，训练：测试 = 3.43	acc = 0.5806451612903226
# model_17	trainNum: 869	testNum: 221，训练：测试 = 3.93	acc = 0.9592760180995475
# model_18	trainNum: 4497	testNum: 1092，训练：测试 = 4.12	acc = 0.7545787545787546
# model_19	trainNum: 2237	testNum: 559，训练：测试 = 4.00	acc = 0.7906976744186046
# K = 21	迭代次数： 155
# model_0	trainNum: 923	testNum: 222，训练：测试 = 4.16	acc = 0.6981981981981982
# model_1	trainNum: 476	testNum: 122，训练：测试 = 3.90	acc = 0.9754098360655737
# model_2	trainNum: 2034	testNum: 538，训练：测试 = 3.78	acc = 0.9312267657992565
# model_3	trainNum: 22433	testNum: 5553，训练：测试 = 4.04	acc = 0.7878624167116873
# model_4	trainNum: 657	testNum: 188，训练：测试 = 3.49	acc = 0.8776595744680851
# model_5	trainNum: 982	testNum: 227，训练：测试 = 4.33	acc = 0.960352422907489
# model_6	trainNum: 182	testNum: 43，训练：测试 = 4.23	acc = 0.6976744186046512
# model_7	trainNum: 1435	testNum: 388，训练：测试 = 3.70	acc = 0.9175257731958762
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 7460	testNum: 1914，训练：测试 = 3.90	acc = 0.9164054336468129
# model_10	trainNum: 887	testNum: 200，训练：测试 = 4.43	acc = 0.92
# model_11	trainNum: 1209	testNum: 292，训练：测试 = 4.14	acc = 0.910958904109589
# model_12	trainNum: 693	testNum: 170，训练：测试 = 4.08	acc = 0.9823529411764705
# model_13	trainNum: 214	testNum: 42，训练：测试 = 5.10	acc = 0.8095238095238095
# model_14	trainNum: 34	testNum: 9，训练：测试 = 3.78	acc = 0.6666666666666666
# model_15	trainNum: 13178	testNum: 3295，训练：测试 = 4.00	acc = 0.8871016691957512
# model_16	trainNum: 157	testNum: 46，训练：测试 = 3.41	acc = 0.7391304347826086
# model_17	trainNum: 869	testNum: 221，训练：测试 = 3.93	acc = 0.9502262443438914
# model_18	trainNum: 458	testNum: 130，训练：测试 = 3.52	acc = 0.6538461538461539
# model_19	trainNum: 2252	testNum: 565，训练：测试 = 3.99	acc = 0.7911504424778761
# model_20	trainNum: 4859	testNum: 1185，训练：测试 = 4.10	acc = 0.7468354430379747
# K = 22	迭代次数： 176
# model_0	trainNum: 915	testNum: 221，训练：测试 = 4.14	acc = 0.6968325791855203
# model_1	trainNum: 476	testNum: 122，训练：测试 = 3.90	acc = 0.9754098360655737
# model_2	trainNum: 2006	testNum: 527，训练：测试 = 3.81	acc = 0.9259962049335864
# model_3	trainNum: 22066	testNum: 5463，训练：测试 = 4.04	acc = 0.7876624565257184
# model_4	trainNum: 657	testNum: 188，训练：测试 = 3.49	acc = 0.8776595744680851
# model_5	trainNum: 977	testNum: 225，训练：测试 = 4.34	acc = 0.9644444444444444
# model_6	trainNum: 182	testNum: 43，训练：测试 = 4.23	acc = 0.6976744186046512
# model_7	trainNum: 1447	testNum: 395，训练：测试 = 3.66	acc = 0.8987341772151899
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 6767	testNum: 1738，训练：测试 = 3.89	acc = 0.904487917146145
# model_10	trainNum: 841	testNum: 194，训练：测试 = 4.34	acc = 0.9278350515463918
# model_11	trainNum: 1208	testNum: 292，训练：测试 = 4.14	acc = 0.9075342465753424
# model_12	trainNum: 692	testNum: 170，训练：测试 = 4.07	acc = 0.9823529411764705
# model_13	trainNum: 212	testNum: 42，训练：测试 = 5.05	acc = 0.8095238095238095
# model_14	trainNum: 34	testNum: 9，训练：测试 = 3.78	acc = 0.6666666666666666
# model_15	trainNum: 13188	testNum: 3296，训练：测试 = 4.00	acc = 0.8810679611650486
# model_16	trainNum: 157	testNum: 46，训练：测试 = 3.41	acc = 0.717391304347826
# model_17	trainNum: 869	testNum: 221，训练：测试 = 3.93	acc = 0.9547511312217195
# model_18	trainNum: 457	testNum: 130，训练：测试 = 3.52	acc = 0.6230769230769231
# model_19	trainNum: 2255	testNum: 568，训练：测试 = 3.97	acc = 0.7869718309859155
# model_20	trainNum: 4775	testNum: 1154，训练：测试 = 4.14	acc = 0.7435008665511266
# model_21	trainNum: 1211	testNum: 306，训练：测试 = 3.96	acc = 0.9673202614379085
# K = 23	迭代次数： 99
# model_0	trainNum: 629	testNum: 145，训练：测试 = 4.34	acc = 0.7172413793103448
# model_1	trainNum: 476	testNum: 122，训练：测试 = 3.90	acc = 0.9754098360655737
# model_2	trainNum: 1954	testNum: 515，训练：测试 = 3.79	acc = 0.9242718446601942
# model_3	trainNum: 21355	testNum: 5315，训练：测试 = 4.02	acc = 0.7998118532455315
# model_4	trainNum: 657	testNum: 188，训练：测试 = 3.49	acc = 0.8882978723404256
# model_5	trainNum: 973	testNum: 222，训练：测试 = 4.38	acc = 0.963963963963964
# model_6	trainNum: 165	testNum: 41，训练：测试 = 4.02	acc = 0.6829268292682927
# model_7	trainNum: 1414	testNum: 384，训练：测试 = 3.68	acc = 0.9036458333333334
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 6132	testNum: 1577，训练：测试 = 3.89	acc = 0.8991756499682942
# model_10	trainNum: 837	testNum: 193，训练：测试 = 4.34	acc = 0.9378238341968912
# model_11	trainNum: 1207	testNum: 293，训练：测试 = 4.12	acc = 0.9078498293515358
# model_12	trainNum: 677	testNum: 166，训练：测试 = 4.08	acc = 0.9819277108433735
# model_13	trainNum: 211	testNum: 42，训练：测试 = 5.02	acc = 0.8333333333333334
# model_14	trainNum: 34	testNum: 9，训练：测试 = 3.78	acc = 0.6666666666666666
# model_15	trainNum: 11299	testNum: 2819，训练：测试 = 4.01	acc = 0.8882582476055338
# model_16	trainNum: 157	testNum: 47，训练：测试 = 3.34	acc = 0.723404255319149
# model_17	trainNum: 869	testNum: 221，训练：测试 = 3.93	acc = 0.9457013574660633
# model_18	trainNum: 1806	testNum: 455，训练：测试 = 3.97	acc = 0.7472527472527473
# model_19	trainNum: 2121	testNum: 536，训练：测试 = 3.96	acc = 0.7835820895522388
# model_20	trainNum: 473	testNum: 131，训练：测试 = 3.61	acc = 0.6793893129770993
# model_21	trainNum: 1206	testNum: 306，训练：测试 = 3.94	acc = 0.9575163398692811
# model_22	trainNum: 6740	testNum: 1623，训练：测试 = 4.15	acc = 0.7288971041281578
# K = 24	迭代次数： 94
# model_0	trainNum: 629	testNum: 145，训练：测试 = 4.34	acc = 0.696551724137931
# model_1	trainNum: 476	testNum: 122，训练：测试 = 3.90	acc = 0.9754098360655737
# model_2	trainNum: 1951	testNum: 514，训练：测试 = 3.80	acc = 0.9299610894941635
# model_3	trainNum: 21393	testNum: 5324，训练：测试 = 4.02	acc = 0.8009015777610818
# model_4	trainNum: 657	testNum: 188，训练：测试 = 3.49	acc = 0.8829787234042553
# model_5	trainNum: 974	testNum: 223，训练：测试 = 4.37	acc = 0.9596412556053812
# model_6	trainNum: 165	testNum: 41，训练：测试 = 4.02	acc = 0.7073170731707317
# model_7	trainNum: 1417	testNum: 385，训练：测试 = 3.68	acc = 0.9038961038961039
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 6108	testNum: 1572，训练：测试 = 3.89	acc = 0.9007633587786259
# model_10	trainNum: 836	testNum: 193，训练：测试 = 4.33	acc = 0.927461139896373
# model_11	trainNum: 839	testNum: 209，训练：测试 = 4.01	acc = 0.8851674641148325
# model_12	trainNum: 677	testNum: 166，训练：测试 = 4.08	acc = 0.9819277108433735
# model_13	trainNum: 211	testNum: 42，训练：测试 = 5.02	acc = 0.8095238095238095
# model_14	trainNum: 34	testNum: 9，训练：测试 = 3.78	acc = 0.6666666666666666
# model_15	trainNum: 11215	testNum: 2793，训练：测试 = 4.02	acc = 0.8893662728249194
# model_16	trainNum: 157	testNum: 47，训练：测试 = 3.34	acc = 0.7659574468085106
# model_17	trainNum: 869	testNum: 221，训练：测试 = 3.93	acc = 0.9592760180995475
# model_18	trainNum: 1806	testNum: 455，训练：测试 = 3.97	acc = 0.7384615384615385
# model_19	trainNum: 2104	testNum: 534，训练：测试 = 3.94	acc = 0.7902621722846442
# model_20	trainNum: 473	testNum: 131，训练：测试 = 3.61	acc = 0.6335877862595419
# model_21	trainNum: 1207	testNum: 305，训练：测试 = 3.96	acc = 0.9672131147540983
# model_22	trainNum: 6746	testNum: 1624，训练：测试 = 4.15	acc = 0.729064039408867
# model_23	trainNum: 448	testNum: 107，训练：测试 = 4.19	acc = 0.8785046728971962
# K = 25	迭代次数： 105
# model_0	trainNum: 637	testNum: 147，训练：测试 = 4.33	acc = 0.7074829931972789
# model_1	trainNum: 375	testNum: 91，训练：测试 = 4.12	acc = 0.989010989010989
# model_2	trainNum: 1184	testNum: 293，训练：测试 = 4.04	acc = 0.9453924914675768
# model_3	trainNum: 22438	testNum: 5554，训练：测试 = 4.04	acc = 0.8111271155923658
# model_4	trainNum: 793	testNum: 222，训练：测试 = 3.57	acc = 0.9819819819819819
# model_5	trainNum: 989	testNum: 226，训练：测试 = 4.38	acc = 0.9646017699115044
# model_6	trainNum: 165	testNum: 41，训练：测试 = 4.02	acc = 0.6829268292682927
# model_7	trainNum: 1913	testNum: 503，训练：测试 = 3.80	acc = 0.882703777335984
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 2717	testNum: 695，训练：测试 = 3.91	acc = 0.9136690647482014
# model_10	trainNum: 1377	testNum: 365，训练：测试 = 3.77	acc = 0.9397260273972603
# model_11	trainNum: 845	testNum: 210，训练：测试 = 4.02	acc = 0.9
# model_12	trainNum: 1811	testNum: 458，训练：测试 = 3.95	acc = 0.888646288209607
# model_13	trainNum: 212	testNum: 42，训练：测试 = 5.05	acc = 0.8333333333333334
# model_14	trainNum: 36	testNum: 9，训练：测试 = 4.00	acc = 0.6666666666666666
# model_15	trainNum: 10525	testNum: 2654，训练：测试 = 3.97	acc = 0.8944988696307461
# model_16	trainNum: 158	testNum: 47，训练：测试 = 3.36	acc = 0.7659574468085106
# model_17	trainNum: 1223	testNum: 314，训练：测试 = 3.89	acc = 0.9617834394904459
# model_18	trainNum: 1859	testNum: 463，训练：测试 = 4.02	acc = 0.7429805615550756
# model_19	trainNum: 2178	testNum: 555，训练：测试 = 3.92	acc = 0.7783783783783784
# model_20	trainNum: 485	testNum: 133，训练：测试 = 3.65	acc = 0.631578947368421
# model_21	trainNum: 1221	testNum: 308，训练：测试 = 3.96	acc = 0.974025974025974
# model_22	trainNum: 7072	testNum: 1727，训练：测试 = 4.09	acc = 0.7232194557035322
# model_23	trainNum: 581	testNum: 154，训练：测试 = 3.77	acc = 0.8896103896103896
# model_24	trainNum: 598	testNum: 139，训练：测试 = 4.30	acc = 0.9856115107913669
# K = 26	迭代次数： 111
# model_0	trainNum: 428	testNum: 98，训练：测试 = 4.37	acc = 0.673469387755102
# model_1	trainNum: 375	testNum: 91，训练：测试 = 4.12	acc = 0.989010989010989
# model_2	trainNum: 1179	testNum: 294，训练：测试 = 4.01	acc = 0.9489795918367347
# model_3	trainNum: 22697	testNum: 5637，训练：测试 = 4.03	acc = 0.8091183253503637
# model_4	trainNum: 793	testNum: 222，训练：测试 = 3.57	acc = 0.963963963963964
# model_5	trainNum: 1160	testNum: 279，训练：测试 = 4.16	acc = 0.96415770609319
# model_6	trainNum: 171	testNum: 41，训练：测试 = 4.17	acc = 0.7317073170731707
# model_7	trainNum: 1916	testNum: 505，训练：测试 = 3.79	acc = 0.8811881188118812
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 2715	testNum: 689，训练：测试 = 3.94	acc = 0.918722786647315
# model_10	trainNum: 1391	testNum: 367，训练：测试 = 3.79	acc = 0.9482288828337875
# model_11	trainNum: 845	testNum: 210，训练：测试 = 4.02	acc = 0.9142857142857143
# model_12	trainNum: 1812	testNum: 458，训练：测试 = 3.96	acc = 0.8951965065502183
# model_13	trainNum: 210	testNum: 40，训练：测试 = 5.25	acc = 0.825
# model_14	trainNum: 36	testNum: 9，训练：测试 = 4.00	acc = 0.7777777777777778
# model_15	trainNum: 10666	testNum: 2684，训练：测试 = 3.97	acc = 0.9020119225037257
# model_16	trainNum: 157	testNum: 47，训练：测试 = 3.34	acc = 0.7021276595744681
# model_17	trainNum: 1223	testNum: 314，训练：测试 = 3.89	acc = 0.9585987261146497
# model_18	trainNum: 1156	testNum: 284，训练：测试 = 4.07	acc = 0.7007042253521126
# model_19	trainNum: 2177	testNum: 555，训练：测试 = 3.92	acc = 0.7783783783783784
# model_20	trainNum: 467	testNum: 131，训练：测试 = 3.56	acc = 0.6335877862595419
# model_21	trainNum: 1223	testNum: 308，训练：测试 = 3.97	acc = 0.9707792207792207
# model_22	trainNum: 6717	testNum: 1631，训练：测试 = 4.12	acc = 0.727161250766401
# model_23	trainNum: 560	testNum: 151，训练：测试 = 3.71	acc = 0.9072847682119205
# model_24	trainNum: 598	testNum: 139，训练：测试 = 4.30	acc = 0.9856115107913669
# model_25	trainNum: 720	testNum: 166，训练：测试 = 4.34	acc = 0.8554216867469879
# K = 27	迭代次数： 97
# model_0	trainNum: 435	testNum: 102，训练：测试 = 4.26	acc = 0.6372549019607843
# model_1	trainNum: 379	testNum: 90，训练：测试 = 4.21	acc = 0.9888888888888889
# model_2	trainNum: 488	testNum: 120，训练：测试 = 4.07	acc = 0.9583333333333334
# model_3	trainNum: 24542	testNum: 6114，训练：测试 = 4.01	acc = 0.8171409878966307
# model_4	trainNum: 662	testNum: 193，训练：测试 = 3.43	acc = 0.8963730569948186
# model_5	trainNum: 947	testNum: 209，训练：测试 = 4.53	acc = 0.9569377990430622
# model_6	trainNum: 168	testNum: 41，训练：测试 = 4.10	acc = 0.7073170731707317
# model_7	trainNum: 1425	testNum: 381，训练：测试 = 3.74	acc = 0.910761154855643
# model_8	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_9	trainNum: 2422	testNum: 619，训练：测试 = 3.91	acc = 0.9143780290791599
# model_10	trainNum: 1317	testNum: 350，训练：测试 = 3.76	acc = 0.9371428571428572
# model_11	trainNum: 865	testNum: 214，训练：测试 = 4.04	acc = 0.8878504672897196
# model_12	trainNum: 505	testNum: 129，训练：测试 = 3.91	acc = 0.9612403100775194
# model_13	trainNum: 215	testNum: 42，训练：测试 = 5.12	acc = 0.8571428571428571
# model_14	trainNum: 34	testNum: 9，训练：测试 = 3.78	acc = 0.7777777777777778
# model_15	trainNum: 9793	testNum: 2460，训练：测试 = 3.98	acc = 0.9073170731707317
# model_16	trainNum: 158	testNum: 47，训练：测试 = 3.36	acc = 0.7872340425531915
# model_17	trainNum: 873	testNum: 223，训练：测试 = 3.91	acc = 0.9551569506726457
# model_18	trainNum: 1198	testNum: 302，训练：测试 = 3.97	acc = 0.7119205298013245
# model_19	trainNum: 2309	testNum: 590，训练：测试 = 3.91	acc = 0.788135593220339
# model_20	trainNum: 485	testNum: 134，训练：测试 = 3.62	acc = 0.6492537313432836
# model_21	trainNum: 1220	testNum: 308，训练：测试 = 3.96	acc = 0.9675324675324676
# model_22	trainNum: 7762	testNum: 1917，训练：测试 = 4.05	acc = 0.7214397496087637
# model_23	trainNum: 463	testNum: 108，训练：测试 = 4.29	acc = 0.8703703703703703
# model_24	trainNum: 765	testNum: 174，训练：测试 = 4.40	acc = 0.9022988505747126
# model_25	trainNum: 776	testNum: 175，训练：测试 = 4.43	acc = 0.8514285714285714
# model_26	trainNum: 1186	testNum: 299，训练：测试 = 3.97	acc = 0.9531772575250836
# K = 28	迭代次数： 90
# model_0	trainNum: 435	testNum: 101，训练：测试 = 4.31	acc = 0.6138613861386139
# model_1	trainNum: 355	testNum: 85，训练：测试 = 4.18	acc = 1.0
# model_2	trainNum: 484	testNum: 120，训练：测试 = 4.03	acc = 0.9583333333333334
# model_3	trainNum: 24484	testNum: 6090，训练：测试 = 4.02	acc = 0.8146141215106733
# model_4	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_5	trainNum: 1228	testNum: 298，训练：测试 = 4.12	acc = 0.9664429530201343
# model_6	trainNum: 168	testNum: 41，训练：测试 = 4.10	acc = 0.6829268292682927
# model_7	trainNum: 1417	testNum: 379，训练：测试 = 3.74	acc = 0.9102902374670184
# model_8	trainNum: 172	testNum: 33，训练：测试 = 5.21	acc = 0.9393939393939394
# model_9	trainNum: 2385	testNum: 609，训练：测试 = 3.92	acc = 0.8949096880131363
# model_10	trainNum: 1320	testNum: 350，训练：测试 = 3.77	acc = 0.9371428571428572
# model_11	trainNum: 865	testNum: 215，训练：测试 = 4.02	acc = 0.9069767441860465
# model_12	trainNum: 505	testNum: 129，训练：测试 = 3.91	acc = 0.9767441860465116
# model_13	trainNum: 215	testNum: 42，训练：测试 = 5.12	acc = 0.8571428571428571
# model_14	trainNum: 33	testNum: 9，训练：测试 = 3.67	acc = 0.6666666666666666
# model_15	trainNum: 9589	testNum: 2413，训练：测试 = 3.97	acc = 0.9071694985495234
# model_16	trainNum: 158	testNum: 47，训练：测试 = 3.36	acc = 0.7446808510638298
# model_17	trainNum: 873	testNum: 223，训练：测试 = 3.91	acc = 0.9551569506726457
# model_18	trainNum: 486	testNum: 134，训练：测试 = 3.63	acc = 0.6343283582089553
# model_19	trainNum: 2269	testNum: 576，训练：测试 = 3.94	acc = 0.7881944444444444
# model_20	trainNum: 1221	testNum: 302，训练：测试 = 4.04	acc = 0.6887417218543046
# model_21	trainNum: 1216	testNum: 307，训练：测试 = 3.96	acc = 0.9804560260586319
# model_22	trainNum: 7701	testNum: 1901，训练：测试 = 4.05	acc = 0.7196212519726459
# model_23	trainNum: 464	testNum: 108，训练：测试 = 4.30	acc = 0.8796296296296297
# model_24	trainNum: 769	testNum: 175，训练：测试 = 4.39	acc = 0.9142857142857143
# model_25	trainNum: 738	testNum: 170，训练：测试 = 4.34	acc = 0.8588235294117647
# model_26	trainNum: 1179	testNum: 300，训练：测试 = 3.93	acc = 0.9533333333333334
# model_27	trainNum: 663	testNum: 193，训练：测试 = 3.44	acc = 0.8911917098445595
# K = 29	迭代次数： 88
# model_0	trainNum: 434	testNum: 101，训练：测试 = 4.30	acc = 0.6435643564356436
# model_1	trainNum: 356	testNum: 85，训练：测试 = 4.19	acc = 1.0
# model_2	trainNum: 484	testNum: 120，训练：测试 = 4.03	acc = 0.9583333333333334
# model_3	trainNum: 24418	testNum: 6080，训练：测试 = 4.02	acc = 0.815625
# model_4	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_5	trainNum: 1144	testNum: 288，训练：测试 = 3.97	acc = 0.96875
# model_6	trainNum: 168	testNum: 41，训练：测试 = 4.10	acc = 0.6585365853658537
# model_7	trainNum: 1420	testNum: 380，训练：测试 = 3.74	acc = 0.9078947368421053
# model_8	trainNum: 172	testNum: 33，训练：测试 = 5.21	acc = 0.9393939393939394
# model_9	trainNum: 2372	testNum: 605，训练：测试 = 3.92	acc = 0.9057851239669421
# model_10	trainNum: 1322	testNum: 349，训练：测试 = 3.79	acc = 0.9426934097421203
# model_11	trainNum: 865	testNum: 214，训练：测试 = 4.04	acc = 0.897196261682243
# model_12	trainNum: 505	testNum: 129，训练：测试 = 3.91	acc = 0.9767441860465116
# model_13	trainNum: 210	testNum: 40，训练：测试 = 5.25	acc = 0.85
# model_14	trainNum: 33	testNum: 9，训练：测试 = 3.67	acc = 0.6666666666666666
# model_15	trainNum: 9525	testNum: 2391，训练：测试 = 3.98	acc = 0.9100794646591385
# model_16	trainNum: 160	testNum: 47，训练：测试 = 3.40	acc = 0.7659574468085106
# model_17	trainNum: 873	testNum: 223，训练：测试 = 3.91	acc = 0.9551569506726457
# model_18	trainNum: 475	testNum: 129，训练：测试 = 3.68	acc = 0.6434108527131783
# model_19	trainNum: 2257	testNum: 575，训练：测试 = 3.93	acc = 0.7982608695652174
# model_20	trainNum: 1175	testNum: 298，训练：测试 = 3.94	acc = 0.697986577181208
# model_21	trainNum: 1215	testNum: 306，训练：测试 = 3.97	acc = 0.9640522875816994
# model_22	trainNum: 7725	testNum: 1908，训练：测试 = 4.05	acc = 0.7180293501048218
# model_23	trainNum: 464	testNum: 108，训练：测试 = 4.30	acc = 0.8796296296296297
# model_24	trainNum: 769	testNum: 175，训练：测试 = 4.39	acc = 0.9142857142857143
# model_25	trainNum: 723	testNum: 164，训练：测试 = 4.41	acc = 0.8475609756097561
# model_26	trainNum: 1178	testNum: 298，训练：测试 = 3.95	acc = 0.9563758389261745
# model_27	trainNum: 663	testNum: 193，训练：测试 = 3.44	acc = 0.8911917098445595
# model_28	trainNum: 287	testNum: 61，训练：测试 = 4.70	acc = 0.8688524590163934
# K = 30	迭代次数： 229
# model_0	trainNum: 561	testNum: 128，训练：测试 = 4.38	acc = 0.6484375
# model_1	trainNum: 371	testNum: 89，训练：测试 = 4.17	acc = 0.9887640449438202
# model_2	trainNum: 373	testNum: 94，训练：测试 = 3.97	acc = 0.9574468085106383
# model_3	trainNum: 9873	testNum: 2507，训练：测试 = 3.94	acc = 0.8958915037893898
# model_4	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_5	trainNum: 1124	testNum: 283，训练：测试 = 3.97	acc = 0.9893992932862191
# model_6	trainNum: 169	testNum: 43，训练：测试 = 3.93	acc = 0.6744186046511628
# model_7	trainNum: 1399	testNum: 376，训练：测试 = 3.72	acc = 0.9042553191489362
# model_8	trainNum: 174	testNum: 37，训练：测试 = 4.70	acc = 0.8918918918918919
# model_9	trainNum: 1194	testNum: 308，训练：测试 = 3.88	acc = 0.9058441558441559
# model_10	trainNum: 1340	testNum: 351，训练：测试 = 3.82	acc = 0.9373219373219374
# model_11	trainNum: 849	testNum: 211，训练：测试 = 4.02	acc = 0.8862559241706162
# model_12	trainNum: 451	testNum: 116，训练：测试 = 3.89	acc = 0.9827586206896551
# model_13	trainNum: 204	testNum: 41，训练：测试 = 4.98	acc = 0.8048780487804879
# model_14	trainNum: 33	testNum: 9，训练：测试 = 3.67	acc = 0.7777777777777778
# model_15	trainNum: 3023	testNum: 778，训练：测试 = 3.89	acc = 0.8933161953727506
# model_16	trainNum: 157	testNum: 46，训练：测试 = 3.41	acc = 0.7391304347826086
# model_17	trainNum: 872	testNum: 223，训练：测试 = 3.91	acc = 0.9551569506726457
# model_18	trainNum: 322	testNum: 80，训练：测试 = 4.03	acc = 0.8625
# model_19	trainNum: 2123	testNum: 547，训练：测试 = 3.88	acc = 0.7824497257769653
# model_20	trainNum: 7899	testNum: 1958，训练：测试 = 4.03	acc = 0.7257405515832482
# model_21	trainNum: 1221	testNum: 307，训练：测试 = 3.98	acc = 0.9739413680781759
# model_22	trainNum: 21518	testNum: 5292，训练：测试 = 4.07	acc = 0.8176492819349962
# model_23	trainNum: 461	testNum: 108，训练：测试 = 4.27	acc = 0.8425925925925926
# model_24	trainNum: 819	testNum: 189，训练：测试 = 4.33	acc = 0.9259259259259259
# model_25	trainNum: 2277	testNum: 560，训练：测试 = 4.07	acc = 0.7375
# model_26	trainNum: 1174	testNum: 291，训练：测试 = 4.03	acc = 0.9553264604810997
# model_27	trainNum: 660	testNum: 190，训练：测试 = 3.47	acc = 0.8789473684210526
# model_28	trainNum: 299	testNum: 64，训练：测试 = 4.67	acc = 0.859375
# model_29	trainNum: 452	testNum: 124，训练：测试 = 3.65	acc = 0.6370967741935484
# K = 31	迭代次数： 201
# model_0	trainNum: 542	testNum: 121，训练：测试 = 4.48	acc = 0.7024793388429752
# model_1	trainNum: 308	testNum: 73，训练：测试 = 4.22	acc = 1.0
# model_2	trainNum: 381	testNum: 96，训练：测试 = 3.97	acc = 0.9583333333333334
# model_3	trainNum: 10604	testNum: 2654，训练：测试 = 4.00	acc = 0.8907309721175584
# model_4	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_5	trainNum: 1090	testNum: 280，训练：测试 = 3.89	acc = 0.9821428571428571
# model_6	trainNum: 169	testNum: 42，训练：测试 = 4.02	acc = 0.6666666666666666
# model_7	trainNum: 1398	testNum: 377，训练：测试 = 3.71	acc = 0.9124668435013262
# model_8	trainNum: 178	testNum: 37，训练：测试 = 4.81	acc = 0.918918918918919
# model_9	trainNum: 1222	testNum: 313，训练：测试 = 3.90	acc = 0.9009584664536742
# model_10	trainNum: 1391	testNum: 363，训练：测试 = 3.83	acc = 0.928374655647383
# model_11	trainNum: 837	testNum: 208，训练：测试 = 4.02	acc = 0.8894230769230769
# model_12	trainNum: 456	testNum: 118，训练：测试 = 3.86	acc = 0.9915254237288136
# model_13	trainNum: 205	testNum: 39，训练：测试 = 5.26	acc = 0.8717948717948718
# model_14	trainNum: 33	testNum: 9，训练：测试 = 3.67	acc = 0.7777777777777778
# model_15	trainNum: 3931	testNum: 998，训练：测试 = 3.94	acc = 0.8807615230460922
# model_16	trainNum: 158	testNum: 47，训练：测试 = 3.36	acc = 0.7659574468085106
# model_17	trainNum: 873	testNum: 223，训练：测试 = 3.91	acc = 0.9551569506726457
# model_18	trainNum: 322	testNum: 79，训练：测试 = 4.08	acc = 0.8481012658227848
# model_19	trainNum: 2112	testNum: 543，训练：测试 = 3.89	acc = 0.7937384898710865
# model_20	trainNum: 6734	testNum: 1632，训练：测试 = 4.13	acc = 0.7199754901960784
# model_21	trainNum: 1204	testNum: 306，训练：测试 = 3.93	acc = 0.9640522875816994
# model_22	trainNum: 20892	testNum: 5192，训练：测试 = 4.02	acc = 0.8043143297380585
# model_23	trainNum: 733	testNum: 190，训练：测试 = 3.86	acc = 0.9473684210526315
# model_24	trainNum: 836	testNum: 191，训练：测试 = 4.38	acc = 0.9214659685863874
# model_25	trainNum: 1730	testNum: 439，训练：测试 = 3.94	acc = 0.7289293849658315
# model_26	trainNum: 1169	testNum: 288，训练：测试 = 4.06	acc = 0.9513888888888888
# model_27	trainNum: 659	testNum: 190，训练：测试 = 3.47	acc = 0.8736842105263158
# model_28	trainNum: 294	testNum: 63，训练：测试 = 4.67	acc = 0.873015873015873
# model_29	trainNum: 484	testNum: 132，训练：测试 = 3.67	acc = 0.6515151515151515
# model_30	trainNum: 447	testNum: 107，训练：测试 = 4.18	acc = 0.8598130841121495
# K = 32	迭代次数： 198
# model_0	trainNum: 539	testNum: 121，训练：测试 = 4.45	acc = 0.6611570247933884
# model_1	trainNum: 310	testNum: 73，训练：测试 = 4.25	acc = 1.0
# model_2	trainNum: 384	testNum: 97，训练：测试 = 3.96	acc = 0.9587628865979382
# model_3	trainNum: 10814	testNum: 2730，训练：测试 = 3.96	acc = 0.873992673992674
# model_4	trainNum: 48	testNum: 10，训练：测试 = 4.80	acc = 1.0
# model_5	trainNum: 364	testNum: 84，训练：测试 = 4.33	acc = 0.9404761904761905
# model_6	trainNum: 169	testNum: 42，训练：测试 = 4.02	acc = 0.6904761904761905
# model_7	trainNum: 818	testNum: 200，训练：测试 = 4.09	acc = 0.89
# model_8	trainNum: 165	testNum: 34，训练：测试 = 4.85	acc = 0.9117647058823529
# model_9	trainNum: 4640	testNum: 1197，训练：测试 = 3.88	acc = 0.9047619047619048
# model_10	trainNum: 1417	testNum: 374，训练：测试 = 3.79	acc = 0.9411764705882353
# model_11	trainNum: 835	testNum: 206，训练：测试 = 4.05	acc = 0.912621359223301
# model_12	trainNum: 456	testNum: 118，训练：测试 = 3.86	acc = 0.9915254237288136
# model_13	trainNum: 204	testNum: 39，训练：测试 = 5.23	acc = 0.8205128205128205
# model_14	trainNum: 33	testNum: 9，训练：测试 = 3.67	acc = 0.6666666666666666
# model_15	trainNum: 1972	testNum: 501，训练：测试 = 3.94	acc = 0.9441117764471058
# model_16	trainNum: 158	testNum: 47，训练：测试 = 3.36	acc = 0.7659574468085106
# model_17	trainNum: 871	testNum: 222，训练：测试 = 3.92	acc = 0.954954954954955
# model_18	trainNum: 322	testNum: 79，训练：测试 = 4.08	acc = 0.8481012658227848
# model_19	trainNum: 2021	testNum: 515，训练：测试 = 3.92	acc = 0.7728155339805826
# model_20	trainNum: 6471	testNum: 1571，训练：测试 = 4.12	acc = 0.7186505410566518
# model_21	trainNum: 1194	testNum: 301，训练：测试 = 3.97	acc = 0.9667774086378738
# model_22	trainNum: 20273	testNum: 5034，训练：测试 = 4.03	acc = 0.800357568533969
# model_23	trainNum: 1264	testNum: 322，训练：测试 = 3.93	acc = 0.8975155279503105
# model_24	trainNum: 251	testNum: 51，训练：测试 = 4.92	acc = 1.0
# model_25	trainNum: 1694	testNum: 427，训练：测试 = 3.97	acc = 0.7283372365339579
# model_26	trainNum: 1137	testNum: 274，训练：测试 = 4.15	acc = 0.948905109489051
# model_27	trainNum: 660	testNum: 191，训练：测试 = 3.46	acc = 0.8848167539267016
# model_28	trainNum: 286	testNum: 60，训练：测试 = 4.77	acc = 0.8666666666666667
# model_29	trainNum: 478	testNum: 130，训练：测试 = 3.68	acc = 0.6307692307692307
# model_30	trainNum: 449	testNum: 107，训练：测试 = 4.20	acc = 0.8598130841121495
# model_31	trainNum: 743	testNum: 194，训练：测试 = 3.83	acc = 0.9381443298969072
# d:\python37\lib\site-packages\ipykernel_launcher.py:39: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray

# %%
#plt.figure()
#plt.subplot(211)
plt.title("meanAccuracy", fontsize=24)
plt.xlabel("num_cluster", fontsize=14)
plt.ylabel("meanAccuracy", fontsize=14)
n_cluster = [i for i in range(1, len(meanAcc) + 1)]
plt.plot(n_cluster, meanAcc, color='blue', label='test accuracy')

plt.grid()
plt.legend()
plt.show()

# %%
#    *** 在这里我们关心哪些人的哪些视频被聚在了一起 ***    #
# 除零警告
# 为什么聚一类，一次都没迭代就收敛了，至少迭代一次吧，tolerance，是不是容忍度太高了
# 聚类中心初始化问题，可能会在迭代过程中出现某个聚类中心中没有样本的情况
